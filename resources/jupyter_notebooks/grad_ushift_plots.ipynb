# %% [markdown]
# # $\partial_i\beta^j$ plots

# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt

mpl.rcParams['mathtext.fontset'] = 'cm'
mpl.rcParams['font.family'] = 'Latin Modern Roman'
plt.rcParams['figure.figsize'] = [9, 9]

font_size = 20

# %% [markdown]
# ## Data

# %%
columns=["x", "y", "z", "dx_bx", "dx_by", "dx_bz","dy_bx", "dy_by", "dy_bz", "dz_bx", "dz_by", "dz_bz"]

file_root = "../../Release/"
config_file_name = "grlensing_config.yaml"
metric_name = "Superimposed Kerr binary in Kerr-Schild coordinates"
component_name = "grad_ushift"
file_format = ".ascii"

file_count = 10

# Load first
file_idx = "0"
file_path = file_root + metric_name + "_" + component_name + "_" + file_idx + file_format
data = np.genfromtxt(file_path)
df = pd.DataFrame(data, columns=columns)

# Load the rest
for idx in range(1, file_count):
    file_idx = str(idx)
    file_path = file_root + metric_name + "_" + component_name + "_" + file_idx + file_format
    data = np.genfromtxt(file_path)
    df = pd.merge(df, pd.DataFrame(data, columns=columns), how="outer")
    
df.sort_values(["x", "y", "z"]);

# %% [markdown]
# ## Selecting a plot point

# %%
# Pick a y-z value
filtered_df = df.loc[((df["y"] == 0.0) & (df["z"] == 0.0))]

# %% [markdown]
# ## Plots

# %%
plt.close("all")
plt.xticks(fontsize = font_size)
plt.yticks(fontsize = font_size)
plt.xlabel("$x$", fontsize = font_size)
plt.ylabel("$\\partial_x\\beta^x$", fontsize = font_size)
plt.plot(filtered_df["x"], filtered_df["dx_bx"])
plt.tight_layout()
plt.show()

# %%
plt.close("all")
plt.xticks(fontsize = font_size)
plt.yticks(fontsize = font_size)
plt.xlabel("$x$", fontsize = font_size)
plt.ylabel("$\\partial_x\\beta^y$", fontsize = font_size)
plt.plot(filtered_df["x"], filtered_df["dx_by"])
plt.tight_layout()
plt.show()

# %%
plt.close("all")
plt.xticks(fontsize = font_size)
plt.yticks(fontsize = font_size)
plt.xlabel("$x$", fontsize = font_size)
plt.ylabel("$\\partial_x\\beta^z$", fontsize = font_size)
plt.plot(filtered_df["x"], filtered_df["dx_bz"])
plt.tight_layout()
plt.show()

# %%
plt.close("all")
plt.xticks(fontsize = font_size)
plt.yticks(fontsize = font_size)
plt.xlabel("$x$", fontsize = font_size)
plt.ylabel("$\\partial_y\\beta^x$", fontsize = font_size)
plt.plot(filtered_df["x"], filtered_df["dy_bx"])
plt.tight_layout()
plt.show()

# %%
plt.close("all")
plt.xticks(fontsize = font_size)
plt.yticks(fontsize = font_size)
plt.xlabel("$x$", fontsize = font_size)
plt.ylabel("$\\partial_y\\beta^y$", fontsize = font_size)
plt.plot(filtered_df["x"], filtered_df["dy_by"])
plt.tight_layout()
plt.show()

# %%
plt.close("all")
plt.xticks(fontsize = font_size)
plt.yticks(fontsize = font_size)
plt.xlabel("$x$", fontsize = font_size)
plt.ylabel("$\\partial_y\\beta^z$", fontsize = font_size)
plt.plot(filtered_df["x"], filtered_df["dy_bz"])
plt.tight_layout()
plt.show()

# %%
plt.close("all")
plt.xticks(fontsize = font_size)
plt.yticks(fontsize = font_size)
plt.xlabel("$x$", fontsize = font_size)
plt.ylabel("$\\partial_z\\beta^x$", fontsize = font_size)
plt.plot(filtered_df["x"], filtered_df["dz_bx"])
plt.tight_layout()
plt.show()

# %%
plt.close("all")
plt.xticks(fontsize = font_size)
plt.yticks(fontsize = font_size)
plt.xlabel("$x$", fontsize = font_size)
plt.ylabel("$\\partial_z\\beta^y$", fontsize = font_size)
plt.plot(filtered_df["x"], filtered_df["dz_by"])
plt.tight_layout()
plt.show()

# %%
plt.close("all")
plt.xticks(fontsize = font_size)
plt.yticks(fontsize = font_size)
plt.xlabel("$x$", fontsize = font_size)
plt.ylabel("$\\partial_z\\beta^z$", fontsize = font_size)
plt.plot(filtered_df["x"], filtered_df["dz_bz"])
plt.tight_layout()
plt.show()
